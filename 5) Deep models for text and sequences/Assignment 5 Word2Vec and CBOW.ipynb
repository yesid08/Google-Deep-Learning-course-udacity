# %% [markdown]
# # Deep Learning
# ## Assignment 5
# The goal of this assignment is to train a Word2Vec skip-gram model over Text8 data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'term', 'a', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.895229
# Nearest to into: butyl, virtuosic, mdma, sontag, delirium, ibos, milner, afar,
# Nearest to after: solanaceae, conciliation, reprinting, weidenfeld, fu, stricken, intracellular, understand,
# Nearest to however: agnesi, boudin, mersey, axiomatization, animosity, kampf, coventry, squandered,
# Nearest to state: piccard, proclamations, asparagales, vengeance, times, anonymously, dissociative, refering,
# Nearest to some: cherries, bipolar, mediators, invitational, carnivore, malvaceae, sociologist, ayrshire,
# Nearest to war: decalogue, delete, hebrew, disparities, garage, estado, overlook, crucifixion,
# Nearest to during: ellipsoid, mick, benefitted, unchanging, invariant, couscous, oeuvres, dwelt,
# Nearest to which: weezer, postseason, etc, flanders, expansionism, skew, aeons, fences,
# Nearest to first: academically, mes, entomology, killing, algemeen, tejada, sincere, solvents,
# Nearest to nine: reggae, vineyard, radiative, lilac, ye, immunodeficiency, dye, greifswald,
# Nearest to years: insure, defensible, ancestors, segmented, coles, delicacies, orbiter, cisc,
# Nearest to up: dhimmi, collectible, cons, marie, agenda, covalent, pld, ghosts,
# Nearest to an: ethology, xers, dict, antonin, barley, ageing, insults, eca,
# Nearest to from: tetum, muddy, warning, failings, cuon, roxbury, earning, cynic,
# Nearest to between: leverett, rambling, geniuses, spool, infatuated, defective, ivies, zoff,
# Nearest to six: ps, moltke, archdukes, pitts, upgrade, kronos, oberon, mansions,
# Average loss at step 2000: 4.371502
# Average loss at step 4000: 3.866313
# Average loss at step 6000: 3.789962
# Average loss at step 8000: 3.687354
# Average loss at step 10000: 3.609256
# Nearest to into: butyl, mdma, ibos, playback, on, virtuosic, savage, poole,
# Nearest to after: solanaceae, fu, at, lakeland, while, icann, test, vauban,
# Nearest to however: homage, joaquin, animosity, agnesi, spent, mersey, boudin, squandered,
# Nearest to state: times, asparagales, comfortable, playoff, buildup, picture, couple, supervising,
# Nearest to some: many, ayrshire, liquidated, itunes, these, eastwood, mediocre, mattered,
# Nearest to war: peacocks, hebrew, relocate, ironclad, inflict, cryogenics, unit, crucifixion,
# Nearest to during: benefitted, bangladesh, oeuvres, smog, proving, riemann, cook, post,
# Nearest to which: that, who, this, it, coler, etc, also, indianapolis,
# Nearest to first: academically, citrate, afloat, pursuits, internetworking, bahr, mes, tejada,
# Nearest to nine: eight, five, six, seven, four, zero, three, two,
# Nearest to years: segmented, slanted, insure, falsity, cisc, oran, mot, orbiter,
# Nearest to up: dhimmi, agenda, collectible, financial, tonkin, automate, covalent, dara,
# Nearest to an: distrusted, grainy, the, dict, pardoned, lewin, constellations, pegbox,
# Nearest to from: in, at, lovely, srivijaya, avenue, maladaptive, abound, into,
# Nearest to between: defective, blossomed, geniuses, rambling, zoff, fang, visigoth, dheas,
# Nearest to six: eight, five, seven, three, nine, four, zero, two,
# Average loss at step 12000: 3.606901
# Average loss at step 14000: 3.572310
# Average loss at step 16000: 3.407146
# Average loss at step 18000: 3.456795
# Average loss at step 20000: 3.542270
# Nearest to into: from, butyl, savage, mdma, playback, as, prototype, iridium,
# Nearest to after: at, before, fu, teaser, through, test, over, later,
# Nearest to however: but, that, which, tenacity, ost, spent, joaquin, nsync,
# Nearest to state: times, fittings, picture, couple, largest, dhyana, disclose, collating,
# Nearest to some: many, these, all, any, other, computers, their, narrowly,
# Nearest to war: peacocks, hebrew, tunnelling, cryogenics, inflict, rainey, relocate, rackham,
# Nearest to during: from, under, at, benefitted, riemann, proving, smog, post,
# Nearest to which: this, that, who, also, it, there, what, but,
# Nearest to first: citrate, academically, pursuits, second, afloat, bahr, aurelius, next,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to years: months, falsity, segmented, slanted, baseman, mot, people, insure,
# Nearest to up: financial, agenda, them, automate, dara, dhimmi, collectible, fugue,
# Nearest to an: the, distrusted, pardoned, royalists, reorganisation, dict, probing, comical,
# Nearest to from: into, between, in, through, during, at, antiquaries, and,
# Nearest to between: from, blossomed, with, killing, rambling, defective, revisited, into,
# Nearest to six: eight, seven, five, four, three, nine, two, zero,
# Average loss at step 22000: 3.500935
# Average loss at step 24000: 3.485869
# Average loss at step 26000: 3.484739
# Average loss at step 28000: 3.477724
# Average loss at step 30000: 3.499883
# Nearest to into: from, under, butyl, savage, through, mdma, playback, iridium,
# Nearest to after: before, during, later, when, test, poset, db, while,
# Nearest to however: but, although, while, spent, that, nsync, though, which,
# Nearest to state: times, dhyana, fittings, theorised, government, buildup, transcription, provinces,
# Nearest to some: many, these, several, their, all, any, other, those,
# Nearest to war: peacocks, tunnelling, rainey, gentle, decalogue, hesse, unit, ironclad,
# Nearest to during: after, at, under, from, in, when, hawaiian, brenda,
# Nearest to which: this, that, what, who, it, also, but, usually,
# Nearest to first: second, citrate, next, afloat, pursuits, aurelius, last, recollection,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to years: months, falsity, baseman, mot, nordisk, slanted, segmented, insure,
# Nearest to up: them, financial, agenda, off, automate, away, him, out,
# Nearest to an: halley, distrusted, tampered, alicante, royalists, quarrying, pegbox, kbit,
# Nearest to from: into, during, between, thorndike, lovely, through, under, charred,
# Nearest to between: with, blossomed, from, against, killing, bisexuals, revisited, waldheim,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Average loss at step 32000: 3.499932
# Average loss at step 34000: 3.494502
# Average loss at step 36000: 3.458401
# Average loss at step 38000: 3.299080
# Average loss at step 40000: 3.430243
# Nearest to into: through, from, savage, butyl, under, iridium, mdma, toward,
# Nearest to after: before, during, when, later, while, poset, test, fu,
# Nearest to however: but, although, while, though, that, spent, perfected, congregationalists,
# Nearest to state: government, provinces, fittings, hall, theorised, dhyana, magnates, dichotomy,
# Nearest to some: many, these, several, any, their, those, nucleophilic, narrowly,
# Nearest to war: peacocks, tunnelling, rainey, gentle, ingrid, rackham, troposphere, cornwallis,
# Nearest to during: after, at, from, under, on, before, centronics, galapagos,
# Nearest to which: that, this, who, also, what, it, there, but,
# Nearest to first: second, next, last, citrate, afloat, recollection, best, pursuits,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to years: months, baseman, days, slanted, times, abstaining, kilometres, underlined,
# Nearest to up: them, off, out, down, agenda, him, cinema, back,
# Nearest to an: the, halley, another, distrusted, pegbox, comical, potawatomi, cass,
# Nearest to from: into, through, in, during, kicker, maladaptive, between, of,
# Nearest to between: with, blossomed, from, against, killing, revisited, bisexuals, before,
# Nearest to six: five, seven, eight, four, nine, three, two, zero,
# Average loss at step 42000: 3.440395
# Average loss at step 44000: 3.460331
# Average loss at step 46000: 3.450901
# Average loss at step 48000: 3.356051
# Average loss at step 50000: 3.387235
# Nearest to into: through, from, savage, mdma, under, within, toward, butyl,
# Nearest to after: before, during, when, while, through, poset, later, time,
# Nearest to however: but, although, while, that, though, where, when, spent,
# Nearest to state: government, fittings, provinces, supervising, hall, couple, methodist, theorised,
# Nearest to some: many, several, these, both, most, those, nucleophilic, their,
# Nearest to war: peacocks, tunnelling, ingrid, rainey, gentle, hesse, paraguay, keenly,
# Nearest to during: after, at, in, when, under, before, from, around,
# Nearest to which: that, this, also, who, what, there, but, usually,
# Nearest to first: second, last, next, only, pursuits, subunit, citrate, best,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to years: months, days, times, baseman, hours, kilometres, weeks, abstaining,
# Nearest to up: off, them, out, down, back, cinema, automate, him,
# Nearest to an: distrusted, pegbox, potawatomi, the, another, halley, tampered, buckner,
# Nearest to from: into, through, during, in, kicker, within, for, and,
# Nearest to between: with, blossomed, against, throughout, from, in, waldheim, bisexuals,
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Average loss at step 52000: 3.434964
# Average loss at step 54000: 3.430414
# Average loss at step 56000: 3.436997
# Average loss at step 58000: 3.396683
# Average loss at step 60000: 3.397710
# Nearest to into: through, from, toward, savage, between, within, under, beehive,
# Nearest to after: before, during, when, while, poset, without, although, through,
# Nearest to however: but, although, though, while, that, when, particularly, which,
# Nearest to state: government, couple, dhyana, supervising, fittings, multiplies, anxiolytics, provinces,
# Nearest to some: many, several, these, those, any, all, both, most,
# Nearest to war: ingrid, tunnelling, rainey, peacocks, warring, petitions, ironclad, traversed,
# Nearest to during: after, before, in, since, when, at, until, hawaiian,
# Nearest to which: that, this, what, who, also, typically, cidre, these,
# Nearest to first: second, last, next, only, same, pursuits, best, citrate,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to years: months, days, times, hours, baseman, weeks, decades, kilometres,
# Nearest to up: off, out, them, down, cinema, back, him, compelled,
# Nearest to an: pegbox, tampered, halley, distrusted, comical, another, discredited, caldera,
# Nearest to from: into, through, thorndike, in, susceptibility, pharos, within, maladaptive,
# Nearest to between: with, blossomed, into, against, revisited, among, toward, from,
# Nearest to six: eight, five, four, nine, seven, three, zero, two,
# Average loss at step 62000: 3.241714
# Average loss at step 64000: 3.247576
# Average loss at step 66000: 3.402323
# Average loss at step 68000: 3.391375
# Average loss at step 70000: 3.360106
# Nearest to into: through, from, within, toward, savage, under, in, towards,
# Nearest to after: before, during, when, while, without, through, despite, poset,
# Nearest to however: but, although, though, that, while, when, where, if,
# Nearest to state: government, dhyana, states, legislature, dominance, fittings, dichotomy, republic,
# Nearest to some: many, several, these, all, any, both, most, various,
# Nearest to war: ingrid, tunnelling, peacocks, rainey, rackham, traversed, warring, gentle,
# Nearest to during: after, before, in, since, under, until, within, galapagos,
# Nearest to which: that, this, what, also, usually, but, typically, cidre,
# Nearest to first: second, last, next, third, same, pursuits, traumas, magnitude,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to years: months, days, hours, decades, times, kilometres, weeks, year,
# Nearest to up: out, off, them, down, back, cinema, uttar, agenda,
# Nearest to an: pegbox, the, halley, potawatomi, distrusted, rationalism, another, caldera,
# Nearest to from: through, into, within, thorndike, pharos, kicker, during, organometallic,
# Nearest to between: with, among, within, blossomed, rambling, into, against, from,
# Nearest to six: eight, seven, four, nine, five, three, zero, two,
# Average loss at step 72000: 3.379070
# Average loss at step 74000: 3.352867
# Average loss at step 76000: 3.324595
# Average loss at step 78000: 3.352887
# Average loss at step 80000: 3.378461
# Nearest to into: through, from, toward, within, towards, under, savage, mdma,
# Nearest to after: before, during, when, without, while, despite, through, from,
# Nearest to however: but, although, though, that, while, cases, except, when,
# Nearest to state: government, states, dhyana, dominance, cutbacks, princeton, coordination, fittings,
# Nearest to some: many, several, these, various, most, both, auschwitz, all,
# Nearest to war: ingrid, tunnelling, thrift, paraguay, traversed, gentle, peacocks, warring,
# Nearest to during: after, in, before, when, since, despite, until, under,
# Nearest to which: this, that, also, usually, what, both, typically, asteroids,
# Nearest to first: last, second, next, third, traumas, best, only, competitions,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to years: months, days, hours, decades, times, weeks, year, centuries,
# Nearest to up: off, out, down, them, back, cinema, him, uttar,
# Nearest to an: distrusted, pegbox, generated, clutching, lewin, comical, covered, sonata,
# Nearest to from: through, into, within, during, after, kicker, before, convening,
# Nearest to between: among, with, within, blossomed, rambling, ast, against, receptors,
# Nearest to six: four, seven, eight, five, three, nine, zero, two,
# Average loss at step 82000: 3.403869
# Average loss at step 84000: 3.411842
# Average loss at step 86000: 3.391488
# Average loss at step 88000: 3.354649
# Average loss at step 90000: 3.365571
# Nearest to into: through, from, toward, within, under, around, towards, construed,
# Nearest to after: before, during, when, without, while, despite, upon, through,
# Nearest to however: but, although, though, while, cases, that, especially, since,
# Nearest to state: government, city, dhyana, states, meals, dominance, orphan, dichotomy,
# Nearest to some: many, several, these, both, any, various, most, all,
# Nearest to war: ingrid, thrift, traversed, gentle, paraguay, tunnelling, warring, rackham,
# Nearest to during: after, until, in, before, since, when, despite, throughout,
# Nearest to which: that, what, usually, this, also, who, but, both,
# Nearest to first: second, last, next, earliest, pursuits, best, competitions, third,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to years: months, days, hours, decades, year, weeks, times, kilometres,
# Nearest to up: out, off, down, them, back, away, him, uttar,
# Nearest to an: distrusted, another, pegbox, caldera, comical, potawatomi, clutching, overtaking,
# Nearest to from: through, into, during, within, thorndike, pharos, organometallic, under,
# Nearest to between: with, among, within, blossomed, against, toward, jul, rambling,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Average loss at step 92000: 3.396521
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-4a1c0b8bda51> in <module>()
#       9       batch_size, num_skips, skip_window)
#      10     feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
# ---> 11     _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#      12     average_loss += l
#      13     if step % 2000 == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     787     try:
#     788       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 789                          run_metadata_ptr)
#     790       if run_metadata:
#     791         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     995     if final_fetches or final_targets:
#     996       results = self._do_run(handle, final_targets, final_fetches,
# --> 997                              feed_dict_string, options, run_metadata)
#     998     else:
#     999       results = []
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1130     if handle is None:
#    1131       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1132                            target_list, options, run_metadata)
#    1133     else:
#    1134       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1137   def _do_call(self, fn, *args):
#    1138     try:
# -> 1139       return fn(*args)
#    1140     except errors.OpError as e:
#    1141       message = compat.as_text(e.message)
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1119         return tf_session.TF_Run(session, options,
#    1120                                  feed_dict, fetch_list, target_list,
# -> 1121                                  status, run_metadata)
#    1122
#    1123     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# # Problem
# An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %%
data_index = 0

# skip_window: int : How many words to consider left and right.
def generate_cbow_batch(batch_size, skip_window):
  global data_index
#   assert batch_size % num_skips == 0
#   assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, skip_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
#   buffer = []
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
  for i in range(batch_size):
    batch[i] = list(buffer)[:skip_window] + list(buffer)[skip_window+1:]
    labels[i] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels

# %%
# CBOW model

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  # note the different input dimensions for the CBOW model
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # note the sum over the context embeddings for the CBOW model
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.reduce_sum(embed, 1)

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.845387
# Nearest to has: uphold, lem, antimatter, siddha, miniaturized, horsepower, undercoat, tuttle,
# Nearest to use: albertine, correlatives, organisations, proxima, vesta, exaggeration, actionscript, roses,
# Nearest to one: lively, ribbentrop, screwtape, romans, dvi, capable, murdering, enthalpy,
# Nearest to more: reigning, dispensed, collated, certification, glucagon, luanda, hampstead, undermining,
# Nearest to if: monotone, investigator, lamorna, jest, verso, vh, sienkiewicz, blondie,
# Nearest to which: indicators, rdos, gloria, edwina, fukuda, orchards, silverman, amundsen,
# Nearest to i: bouchard, their, schedules, wilder, cantor, aquifers, shaman, tis,
# Nearest to their: eridanus, drawn, cypriots, i, almaty, mackey, ramanujan, declaration,
# Nearest to often: samuel, javascript, bara, direction, pipers, philip, jscript, estimating,
# Nearest to th: magnesians, meow, anders, errands, pharmaceutical, joel, mithraea, piccadilly,
# Nearest to he: amer, nye, servius, soundtrack, altaic, permanganate, elaborating, biol,
# Nearest to united: monologue, playstation, songs, bickering, workbench, solicit, bravery, amputation,
# Nearest to d: immediacy, obedience, oeuvres, bethlen, ab, drachmae, iron, plow,
# Nearest to new: resentful, inductance, continue, concealed, bambara, ottoman, marksmanship, craps,
# Nearest to between: seminary, christianization, sheikh, caldwell, rodan, geschichte, kurt, wi,
# Nearest to than: ghana, welcome, benevento, marquise, freiherr, locking, acquisitions, infection,
# Average loss at step 2000: 4.090862
# Average loss at step 4000: 3.566586
# Average loss at step 6000: 3.382045
# Average loss at step 8000: 3.234789
# Average loss at step 10000: 3.177448
# Nearest to has: had, is, have, was, ryukyu, adi, involves, lem,
# Nearest to use: jacinto, solvable, prostitution, correlatives, albertine, cac, intervals, evangelista,
# Nearest to one: eight, six, two, seven, nine, five, four, three,
# Nearest to more: most, very, grown, less, applies, klaip, northerners, medication,
# Nearest to if: earthworms, centralization, atrophy, joliet, tuition, when, orchestration, lct,
# Nearest to which: that, also, what, this, it, who, he, gives,
# Nearest to i: ii, bouchard, reinstatement, cantor, aquifers, repertoire, licks, falsity,
# Nearest to their: his, its, her, the, transition, attempts, briton, sola,
# Nearest to often: also, still, sometimes, javascript, ambushed, generally, devotional, usually,
# Nearest to th: errands, magnesians, interwar, anders, seams, textile, seven, navigational,
# Nearest to he: it, they, she, who, there, centrale, merritt, which,
# Nearest to united: monologue, underdogs, quail, abstractly, solicit, playstation, rest, vesta,
# Nearest to d: b, immediacy, avram, shoulders, accident, plow, oeuvres, threw,
# Nearest to new: christa, resentful, ueshiba, halal, highbury, canossa, tulip, mobile,
# Nearest to between: with, lucasfilm, lobby, engelbert, from, surjective, seminary, hbo,
# Nearest to than: or, convene, hickman, spiritus, burgundian, ghana, acquisitions, zorro,
# Average loss at step 12000: 3.202010
# Average loss at step 14000: 3.155770
# Average loss at step 16000: 3.176877
# Average loss at step 18000: 3.122879
# Average loss at step 20000: 2.991855
# Nearest to has: had, have, was, is, polyhedral, trusting, aides, involves,
# Nearest to use: prostitution, jacinto, solvable, magnification, resolve, organisations, albertine, regardless,
# Nearest to one: six, eight, two, seven, four, five, nine, three,
# Nearest to more: most, less, very, banister, medication, northerners, obfuscated, klaip,
# Nearest to if: when, though, since, jhana, xxv, for, shapeshifting, where,
# Nearest to which: that, this, who, ripe, what, often, also, paley,
# Nearest to i: ii, you, bouchard, he, reinstatement, we, iii, cantor,
# Nearest to their: its, his, her, the, our, your, katsuhiro, akimbo,
# Nearest to often: sometimes, generally, usually, commonly, still, also, which, frequently,
# Nearest to th: six, five, seven, errands, nd, eight, rd, interwar,
# Nearest to he: she, it, they, there, who, i, then, mongolian,
# Nearest to united: quail, abstractly, underdogs, rest, monologue, same, rise, solicit,
# Nearest to d: b, immediacy, avram, accident, threw, implements, shoulders, pearlman,
# Nearest to new: christa, weierstrass, romagna, mobile, quench, arianism, traveller, highbury,
# Nearest to between: with, lucasfilm, engelbert, cw, markham, lobby, through, theosophical,
# Nearest to than: or, bidirectional, spiritus, convene, burgundian, hickman, filed, syrup,
# Average loss at step 22000: 3.070050
# Average loss at step 24000: 3.042663
# Average loss at step 26000: 3.003637
# Average loss at step 28000: 3.031773
# Average loss at step 30000: 3.007150
# Nearest to has: had, have, is, was, involves, having, adi, delgado,
# Nearest to use: sense, solvable, prostitution, resolve, jacinto, allyn, lecturers, intervals,
# Nearest to one: two, three, six, five, seven, nine, four, eight,
# Nearest to more: less, very, most, highly, other, rather, medication, smaller,
# Nearest to if: when, though, where, lubricants, before, jhana, since, follows,
# Nearest to which: that, this, ripe, what, also, however, who, but,
# Nearest to i: ii, g, bouchard, you, we, villainous, iii, she,
# Nearest to their: its, his, her, our, the, your, akimbo, these,
# Nearest to often: sometimes, generally, usually, commonly, frequently, now, still, widely,
# Nearest to th: five, nd, rd, errands, six, interwar, four, indonesians,
# Nearest to he: she, it, they, who, there, permanganate, mongolian, korfball,
# Nearest to united: quail, abstractly, underdogs, monologue, same, solicit, entire, hops,
# Nearest to d: b, avram, immediacy, p, pearlman, accident, chernenko, ab,
# Nearest to new: christa, mobile, naguib, vibrational, arcade, weierstrass, special, bolivia,
# Nearest to between: with, lucasfilm, among, engelbert, offended, within, lobby, lifton,
# Nearest to than: or, but, spiritus, pancreas, convene, tico, ancien, sacrificed,
# Average loss at step 32000: 2.825477
# Average loss at step 34000: 2.955439
# Average loss at step 36000: 2.947091
# Average loss at step 38000: 2.936945
# Average loss at step 40000: 2.930162
# Nearest to has: had, have, is, was, trusting, qaddafi, having, involves,
# Nearest to use: solvable, sense, handwriting, develop, albertine, prostitution, lossy, resolve,
# Nearest to one: two, six, seven, eight, five, three, nine, four,
# Nearest to more: less, most, very, quite, highly, increasingly, extremely, larger,
# Nearest to if: when, though, xxv, since, before, hydra, where, follows,
# Nearest to which: that, this, also, what, usually, ripe, these, who,
# Nearest to i: we, ii, g, you, bouchard, villainous, iii, they,
# Nearest to their: its, his, her, our, your, the, my, switchable,
# Nearest to often: sometimes, usually, commonly, generally, now, still, typically, frequently,
# Nearest to th: nd, rd, errands, interwar, six, indonesians, malawi, breakdance,
# Nearest to he: she, it, they, there, who, we, assesses, khmelnytsky,
# Nearest to united: quail, abstractly, same, entire, solicit, monopolies, monologue, underdogs,
# Nearest to d: b, newt, immediacy, patrician, avram, labia, mirroring, outspoken,
# Nearest to new: christa, marlowe, weierstrass, cove, halal, highbury, special, irs,
# Nearest to between: within, among, with, through, lobby, around, lucasfilm, lifton,
# Nearest to than: or, much, pancreas, contemplative, spiritus, ancien, tico, invariable,
# Average loss at step 42000: 2.952457
# Average loss at step 44000: 2.955713
# Average loss at step 46000: 2.904060
# Average loss at step 48000: 2.864619
# Average loss at step 50000: 2.845193
# Nearest to has: had, have, is, was, since, having, delgado, maintains,
# Nearest to use: handwriting, sense, support, solvable, make, allow, lossy, applies,
# Nearest to one: seven, two, eight, six, four, nine, three, five,
# Nearest to more: less, most, very, quite, rather, highly, larger, electrode,
# Nearest to if: when, though, where, xxv, since, while, before, because,
# Nearest to which: that, what, this, usually, based, ripe, also, still,
# Nearest to i: we, ii, g, you, bouchard, iii, kornbluth, gamsakhurdia,
# Nearest to their: his, its, her, our, your, my, the, switchable,
# Nearest to often: usually, sometimes, generally, commonly, now, typically, still, frequently,
# Nearest to th: nd, rd, errands, third, second, fifth, indonesians, interwar,
# Nearest to he: she, it, they, there, who, we, assesses, khmelnytsky,
# Nearest to united: same, entire, quail, commonwealth, abstractly, monopolies, negev, grenades,
# Nearest to d: b, avram, gu, panda, gokturks, galway, oeuvres, immediacy,
# Nearest to new: christa, weierstrass, marlowe, clockwise, pollack, intercal, slam, different,
# Nearest to between: with, among, within, lucasfilm, theosophical, twig, through, during,
# Nearest to than: or, much, convene, but, pancreas, complicated, iterate, theologically,
# Average loss at step 52000: 2.890121
# Average loss at step 54000: 2.864969
# Average loss at step 56000: 2.860566
# Average loss at step 58000: 2.752102
# Average loss at step 60000: 2.830969
# Nearest to has: had, have, is, was, having, contains, through, delgado,
# Nearest to use: sense, handwriting, make, support, lossy, resolve, allow, importance,
# Nearest to one: two, four, seven, six, eight, five, nine, three,
# Nearest to more: less, most, very, quite, rather, larger, highly, greater,
# Nearest to if: when, though, where, then, before, should, xxv, although,
# Nearest to which: that, what, usually, this, also, who, ripe, instead,
# Nearest to i: g, ii, we, you, geralt, iii, f, dogmatically,
# Nearest to their: its, his, her, our, your, my, the, whose,
# Nearest to often: usually, sometimes, generally, commonly, typically, now, frequently, also,
# Nearest to th: nd, fifth, indonesians, second, rd, third, errands, candide,
# Nearest to he: she, it, they, who, there, we, notified, assesses,
# Nearest to united: monopolies, abstractly, commonwealth, quail, grenades, european, confederate, differentiating,
# Nearest to d: b, avram, g, immediacy, penicillium, gu, yat, ac,
# Nearest to new: christa, weierstrass, specific, cove, lamiales, different, modern, tsuka,
# Nearest to between: among, within, with, through, during, over, tp, including,
# Nearest to than: or, convene, much, flickr, gul, tico, fptp, pancreas,
# Average loss at step 62000: 2.835703
# Average loss at step 64000: 2.774755
# Average loss at step 66000: 2.760571
# Average loss at step 68000: 2.712890
# Average loss at step 70000: 2.781883
# Nearest to has: had, have, is, having, was, contains, maintains, delgado,
# Nearest to use: sense, understanding, resolve, make, allow, cause, consist, handwriting,
# Nearest to one: two, seven, five, three, nine, eight, six, four,
# Nearest to more: less, most, quite, very, highly, rather, increasingly, too,
# Nearest to if: when, though, where, before, should, schwann, because, after,
# Nearest to which: that, this, also, what, usually, who, ripe, typically,
# Nearest to i: we, you, ii, g, v, iii, geralt, bouchard,
# Nearest to their: its, his, her, your, our, whose, the, my,
# Nearest to often: sometimes, usually, commonly, generally, typically, now, still, frequently,
# Nearest to th: fifth, nd, third, rd, second, bytes, indonesians, thirteenth,
# Nearest to he: she, it, they, who, we, there, assesses, eventually,
# Nearest to united: confederate, quail, differentiating, abstractly, monopolies, dominions, european, city,
# Nearest to d: b, immediacy, jan, ois, avram, threw, gu, chernenko,
# Nearest to new: specific, christa, romagna, particular, different, special, retrial, weierstrass,
# Nearest to between: with, among, within, through, tp, in, imaginations, lucasfilm,
# Nearest to than: or, ancien, convene, tico, suggesting, much, sse, pump,
# Average loss at step 72000: 2.795666
# Average loss at step 74000: 2.643689
# Average loss at step 76000: 2.804638
# Average loss at step 78000: 2.828242
# Average loss at step 80000: 2.776020
# Nearest to has: had, have, was, is, contains, having, maintains, provides,
# Nearest to use: sense, allow, importance, cause, applies, definition, solvable, neighbour,
# Nearest to one: two, four, eight, seven, six, three, nine, five,
# Nearest to more: less, very, quite, most, rather, highly, extremely, greater,
# Nearest to if: when, though, where, since, emanuel, before, follows, thesaurus,
# Nearest to which: that, this, what, usually, also, typically, these, ripe,
# Nearest to i: ii, you, we, they, she, he, frida, triomphe,
# Nearest to their: its, his, her, your, our, whose, my, the,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, now, rarely,
# Nearest to th: nd, rd, third, six, eight, five, fifth, tenth,
# Nearest to he: she, it, they, there, we, assesses, who, petty,
# Nearest to united: confederate, european, abstractly, same, monopolies, dominions, quail, differentiating,
# Nearest to d: b, immediacy, gu, jan, ab, chernenko, whenever, ky,
# Nearest to new: specific, former, different, miata, retrial, christa, romagna, aerosmith,
# Nearest to between: with, among, within, theosophical, twig, imaginations, unless, ould,
# Nearest to than: or, convene, tico, much, shortens, suggesting, pump, ancien,
# Average loss at step 82000: 2.666924
# Average loss at step 84000: 2.768072
# Average loss at step 86000: 2.732730
# Average loss at step 88000: 2.751684
# Average loss at step 90000: 2.736014
# Nearest to has: had, have, is, was, contains, having, maintains, dragoons,
# Nearest to use: allow, sense, make, applies, lossy, need, consist, support,
# Nearest to one: four, two, six, eight, seven, nine, five, three,
# Nearest to more: less, most, quite, very, rather, highly, greater, extremely,
# Nearest to if: when, though, before, where, for, follows, although, schwann,
# Nearest to which: that, this, what, also, who, these, typically, based,
# Nearest to i: we, ii, you, they, frida, t, g, oglethorpe,
# Nearest to their: its, his, her, your, our, whose, my, the,
# Nearest to often: usually, sometimes, generally, commonly, typically, frequently, now, rarely,
# Nearest to th: six, eight, nd, third, fifth, five, rd, tenth,
# Nearest to he: she, it, they, there, we, who, assesses, briefly,
# Nearest to united: quail, differentiating, monopolies, abstractly, confederate, dominions, same, bravery,
# Nearest to d: b, ab, gu, immediacy, peabody, c, pearlman, sovereigns,
# Nearest to new: christa, former, romagna, cove, specific, old, nearby, abbey,
# Nearest to between: with, among, within, theosophical, unless, in, imaginations, twig,
# Nearest to than: or, convene, broom, suggesting, even, gul, but, savvy,
# Average loss at step 92000: 2.677282
# Average loss at step 94000: 2.725640
# Average loss at step 96000: 2.699691
# Average loss at step 98000: 2.364190
# Average loss at step 100000: 2.400412
# Nearest to has: had, have, is, was, contains, maintains, having, delgado,
# Nearest to use: sense, lossy, allow, solvable, means, definition, usage, applies,
# Nearest to one: two, six, three, nine, seven, five, four, eight,
# Nearest to more: less, most, very, quite, rather, extremely, highly, larger,
# Nearest to if: when, though, follows, before, unless, greyface, xxv, schwann,
# Nearest to which: that, what, this, also, typically, usually, actually, instead,
# Nearest to i: ii, we, you, frida, t, they, she, jarre,
# Nearest to their: its, his, her, your, our, my, whose, the,
# Nearest to often: usually, sometimes, generally, typically, commonly, frequently, normally, rarely,
# Nearest to th: fifth, nd, third, rd, tenth, indonesians, bytes, sixteenth,
# Nearest to he: she, they, it, there, we, who, even, assesses,
# Nearest to united: confederate, differentiating, caribbean, dominions, quail, monopolies, signing, european,
# Nearest to d: b, immediacy, rebates, jan, sandy, implements, alumnus, peabody,
# Nearest to new: christa, cove, specific, weierstrass, dinneen, satire, romagna, onion,
# Nearest to between: with, among, within, theosophical, imaginations, through, notional, lancet,
# Nearest to than: or, broom, convene, much, gul, workaround, suggesting, pump,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
