# %% [markdown]
# # Deep Learning
# ## Assignment 5
# The goal of this assignment is to train a Word2Vec skip-gram model over Text8 data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'originated', 'term', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.966863
# Nearest to nine: normalised, yellowish, haggard, lakshadweep, highwayman, precarious, atlantans, aiming,
# Nearest to s: intercept, villains, roller, just, theresa, trotskyism, kantele, stepped,
# Nearest to b: glaucus, cena, overstated, danse, purify, sayers, dancehall, dedicated,
# Nearest to about: optimizing, chromosphere, bolton, vehicular, biro, prefer, excavated, wetter,
# Nearest to he: rise, ruble, reptiles, wired, federico, cannibal, presbyters, brokered,
# Nearest to over: gangsters, bred, colombia, panacea, innermost, british, comedy, nance,
# Nearest to its: sailor, ethics, fairgrounds, miracles, chengdu, sub, celestine, roulette,
# Nearest to have: dogbert, sensations, flunitrazepam, azure, poly, processor, murat, sylia,
# Nearest to people: rommel, flattened, analog, influences, fumble, flagpole, christof, markets,
# Nearest to who: plain, feedstock, ideal, assassinate, negated, dolby, closeness, barrister,
# Nearest to no: fiqh, medicines, antidote, anita, lv, virtuosity, marpol, landfills,
# Nearest to up: primitive, u, documenting, fished, arlene, fora, tired, mgm,
# Nearest to not: moravians, fabricated, impresario, susa, dich, scriptures, marianas, networking,
# Nearest to a: vcs, steiger, spaceflights, polos, amen, voltaic, instilled, ics,
# Nearest to by: juice, protesters, witch, boasted, nos, lx, tailback, platforms,
# Nearest to american: flourish, volkswagen, encircled, alemanni, successfully, wallace, cyclase, daimlerchrysler,
# Average loss at step 2000: 4.373822
# Average loss at step 4000: 3.863889
# Average loss at step 6000: 3.789499
# Average loss at step 8000: 3.689683
# Average loss at step 10000: 3.613345
# Nearest to nine: eight, five, six, seven, zero, three, four, two,
# Nearest to s: his, utilitarianism, neutral, amnon, and, zquez, volcano, buildup,
# Nearest to b: d, danse, purify, nudity, dancehall, roulette, catalytic, burglary,
# Nearest to about: only, chromosphere, rohan, prefer, vehicular, confidentiality, biro, outfielder,
# Nearest to he: it, they, she, who, tapered, acupuncture, hurrians, divergent,
# Nearest to over: lampooned, colombia, counselor, fenton, gangsters, at, rsted, disjunction,
# Nearest to its: the, their, his, defend, ethics, sailor, wes, prosecutor,
# Nearest to have: be, had, were, has, are, murat, susanna, do,
# Nearest to people: influences, problems, babrak, argue, fools, flattened, determining, maia,
# Nearest to who: also, he, which, not, seifert, users, no, devries,
# Nearest to no: medicines, anita, who, it, fiqh, stimulated, tempest, turmeric,
# Nearest to up: fished, suite, centrist, kennedys, debris, urbanisation, fora, baptizing,
# Nearest to not: there, it, also, they, who, sacr, scriptures, to,
# Nearest to a: the, this, vcs, combatants, any, manatees, steamships, vertex,
# Nearest to by: was, into, through, with, in, on, be, as,
# Nearest to american: flourish, cyclase, cream, deteriorate, compiles, encircled, urbana, convolutions,
# Average loss at step 12000: 3.606133
# Average loss at step 14000: 3.573209
# Average loss at step 16000: 3.408047
# Average loss at step 18000: 3.461129
# Average loss at step 20000: 3.542306
# Nearest to nine: eight, seven, six, four, five, zero, three, two,
# Nearest to s: morley, scheming, zquez, interconnects, amnon, kropotkin, bordering, pueblo,
# Nearest to b: d, burglary, purify, danse, russian, cleaners, nudity, commuted,
# Nearest to about: rohan, only, chromosphere, ecozone, confidentiality, ton, journeying, nine,
# Nearest to he: it, she, they, who, there, eluded, then, divergent,
# Nearest to over: fenton, lampooned, counselor, forgeries, colombia, professionals, whenever, astronomers,
# Nearest to its: their, his, the, accent, sailor, some, many, defend,
# Nearest to have: had, has, be, were, are, murat, vital, modelling,
# Nearest to people: problems, influences, others, argue, babrak, maia, determining, acres,
# Nearest to who: he, which, often, they, also, seifert, she, martel,
# Nearest to no: medicines, who, thine, this, physicists, stimulated, anita, a,
# Nearest to up: down, them, kennedys, urbanisation, centrist, debris, adept, suite,
# Nearest to not: scriptures, it, they, there, to, sacr, also, you,
# Nearest to a: the, another, this, rum, any, amen, very, vcs,
# Nearest to by: through, into, be, during, against, been, for, with,
# Nearest to american: british, cream, russian, and, french, cyclase, english, compiles,
# Average loss at step 22000: 3.505315
# Average loss at step 24000: 3.487847
# Average loss at step 26000: 3.480786
# Average loss at step 28000: 3.486396
# Average loss at step 30000: 3.501018
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to s: yahya, his, stat, amnon, cheerleader, pygmy, whose, intercept,
# Nearest to b: d, purify, cleaners, danse, burglary, spliced, espionage, yucat,
# Nearest to about: rohan, ton, only, polynesia, prefer, confidentiality, chromosphere, journeying,
# Nearest to he: it, she, they, who, there, never, then, funneled,
# Nearest to over: forgeries, whenever, fenton, lampooned, professionals, oshii, when, journalists,
# Nearest to its: their, his, the, her, accent, sailor, some, levied,
# Nearest to have: had, has, were, are, be, murat, having, vital,
# Nearest to people: problems, others, influences, babrak, acres, men, absurdum, maia,
# Nearest to who: which, he, they, she, seifert, often, also, and,
# Nearest to no: any, stimulated, thine, physicists, every, anita, negri, medicines,
# Nearest to up: down, them, kennedys, urbanisation, him, debris, rugged, adept,
# Nearest to not: they, still, scriptures, there, it, almoravides, festivals, ytv,
# Nearest to a: any, hamill, another, ldap, the, anatole, notting, wexford,
# Nearest to by: in, for, with, under, from, as, progressed, through,
# Nearest to american: british, english, japanese, russian, french, cream, paging, dei,
# Average loss at step 32000: 3.505265
# Average loss at step 34000: 3.499052
# Average loss at step 36000: 3.452700
# Average loss at step 38000: 3.305911
# Average loss at step 40000: 3.431067
# Nearest to nine: eight, seven, six, four, five, zero, three, one,
# Nearest to s: whose, lem, his, yahya, sixes, beggar, doo, pacifica,
# Nearest to b: d, c, mamoru, r, siemens, e, UNK, j,
# Nearest to about: rohan, journeying, on, ibm, imagery, personhood, polynesia, appearances,
# Nearest to he: she, it, they, there, who, we, never, funneled,
# Nearest to over: whenever, journalists, anthology, kurosawa, month, forgeries, lampooned, administrative,
# Nearest to its: their, his, the, her, accent, aqua, levied, roulette,
# Nearest to have: had, has, were, are, be, murat, foucault, vital,
# Nearest to people: problems, men, others, influences, absurdum, sanj, those, viaduct,
# Nearest to who: he, which, often, she, they, also, seifert, mugwort,
# Nearest to no: any, stimulated, physicists, thine, this, every, vcs, than,
# Nearest to up: them, down, him, out, kennedys, urbanisation, rugged, into,
# Nearest to not: still, they, it, never, actually, scriptures, usually, often,
# Nearest to a: another, the, instilled, vcs, decameron, falco, poetical, combatants,
# Nearest to by: through, with, blender, when, as, be, lx, bears,
# Nearest to american: british, japanese, french, russian, australian, canadian, english, national,
# Average loss at step 42000: 3.438028
# Average loss at step 44000: 3.450142
# Average loss at step 46000: 3.452600
# Average loss at step 48000: 3.352955
# Average loss at step 50000: 3.387204
# Nearest to nine: eight, six, seven, four, five, zero, three, two,
# Nearest to s: whose, pacifica, his, epa, and, their, volcano, nem,
# Nearest to b: d, c, r, siemens, defenseless, granville, g, hennig,
# Nearest to about: appearances, rohan, verdun, personhood, ibm, imagery, agung, journeying,
# Nearest to he: she, it, they, who, there, crocker, we, this,
# Nearest to over: thames, kurosawa, doubtless, whenever, anthology, forgeries, peripheral, showtime,
# Nearest to its: their, his, the, her, saxony, levied, accent, sailor,
# Nearest to have: had, has, were, are, be, murat, having, occasionally,
# Nearest to people: men, children, others, influences, problems, absurdum, speakers, jews,
# Nearest to who: he, which, she, they, also, martel, often, mugwort,
# Nearest to no: any, azure, little, thine, always, stimulated, utter, sudanese,
# Nearest to up: down, out, them, him, off, distance, urbanisation, rugged,
# Nearest to not: still, scriptures, never, actually, usually, transpose, longwave, they,
# Nearest to a: another, the, hamill, steamships, any, poetical, magick, chic,
# Nearest to by: through, was, under, blender, during, be, in, against,
# Nearest to american: european, japanese, british, russian, french, australian, clifton, english,
# Average loss at step 52000: 3.439328
# Average loss at step 54000: 3.429796
# Average loss at step 56000: 3.436400
# Average loss at step 58000: 3.395146
# Average loss at step 60000: 3.396412
# Nearest to nine: eight, six, seven, four, five, zero, three, one,
# Nearest to s: whose, pacifica, lem, ftc, gallia, kicks, grasping, mallet,
# Nearest to b: d, c, r, h, wellcome, e, hennig, siemens,
# Nearest to about: rohan, personhood, speculative, imperceptible, bladed, on, appearances, verdun,
# Nearest to he: she, it, they, who, there, we, divergent, rostock,
# Nearest to over: through, around, into, kurosawa, whenever, within, peripheral, command,
# Nearest to its: their, his, her, the, levied, searches, saxony, your,
# Nearest to have: had, has, are, were, be, murat, having, believe,
# Nearest to people: men, others, absurdum, those, children, speakers, countries, women,
# Nearest to who: he, which, often, they, still, she, never, mugwort,
# Nearest to no: any, little, thine, utter, stimulated, a, islet, refusing,
# Nearest to up: down, out, them, him, off, distance, rugged, robe,
# Nearest to not: still, actually, scriptures, usually, now, to, never, they,
# Nearest to a: another, any, the, didgeridoo, cassell, no, topology, jts,
# Nearest to by: through, with, without, against, under, patass, unmik, mufti,
# Nearest to american: european, british, australian, japanese, russian, english, cuisine, irish,
# Average loss at step 62000: 3.239871
# Average loss at step 64000: 3.256225
# Average loss at step 66000: 3.408265
# Average loss at step 68000: 3.396736
# Average loss at step 70000: 3.361155
# Nearest to nine: eight, six, seven, five, four, zero, three, one,
# Nearest to s: whose, insecticide, pacifica, comnenus, backpacker, nem, samael, amnon,
# Nearest to b: d, wellcome, h, r, c, relapse, diffie, hennig,
# Nearest to about: rohan, on, personhood, bladed, speculative, appearances, imagery, eldorado,
# Nearest to he: she, it, they, there, who, we, crocker, never,
# Nearest to over: around, through, thames, within, forgeries, kurosawa, on, showtime,
# Nearest to its: their, his, her, the, your, levied, accent, kiang,
# Nearest to have: had, has, were, are, be, having, murat, tend,
# Nearest to people: men, women, children, others, members, absurdum, countries, speakers,
# Nearest to who: he, which, they, she, often, martel, still, tetrarchy,
# Nearest to no: any, little, there, always, stimulated, refusing, millionth, zout,
# Nearest to up: down, them, out, off, him, distance, kennedys, rugged,
# Nearest to not: still, now, actually, never, usually, scriptures, generally, there,
# Nearest to a: another, the, cassell, any, poetical, replicas, enough, vcs,
# Nearest to by: through, using, without, in, be, unmik, from, blender,
# Nearest to american: european, british, australian, english, canadian, japanese, irish, cuisine,
# Average loss at step 72000: 3.376507
# Average loss at step 74000: 3.349934
# Average loss at step 76000: 3.320089
# Average loss at step 78000: 3.351788
# Average loss at step 80000: 3.381210
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to s: whose, yahya, lem, circumventing, insecticide, elmer, nem, falsification,
# Nearest to b: d, c, wellcome, h, mamoru, r, relapse, radians,
# Nearest to about: personhood, rohan, approximately, appearances, imperceptible, verdun, amusing, over,
# Nearest to he: she, it, they, there, we, who, never, funneled,
# Nearest to over: around, within, into, thames, through, off, oshii, tossing,
# Nearest to its: their, his, her, your, the, accent, levied, kiang,
# Nearest to have: had, has, are, be, were, having, murat, grassroots,
# Nearest to people: men, women, children, members, others, absurdum, speakers, torre,
# Nearest to who: he, often, which, they, usually, she, mugwort, still,
# Nearest to no: little, always, any, internetwork, thine, refusing, mauser, stimulated,
# Nearest to up: down, out, off, them, him, distance, back, robe,
# Nearest to not: still, actually, now, usually, never, it, always, we,
# Nearest to a: another, the, cassell, hamill, steamships, curricula, markedly, enough,
# Nearest to by: through, unmik, using, lx, shunning, when, identifies, protesters,
# Nearest to american: british, european, australian, japanese, german, english, french, awami,
# Average loss at step 82000: 3.408369
# Average loss at step 84000: 3.410977
# Average loss at step 86000: 3.390434
# Average loss at step 88000: 3.355380
# Average loss at step 90000: 3.366131
# Nearest to nine: eight, seven, six, five, four, zero, three, one,
# Nearest to s: whose, pacifica, nem, amnon, his, srpska, although, noll,
# Nearest to b: d, wellcome, c, h, relapse, diffie, p, e,
# Nearest to about: rohan, personhood, condone, approximately, bladed, sing, regarding, amusing,
# Nearest to he: she, it, they, there, who, we, later, never,
# Nearest to over: around, within, off, through, command, forgeries, caviar, thames,
# Nearest to its: their, his, her, the, your, searches, levied, my,
# Nearest to have: had, has, were, be, having, are, require, murat,
# Nearest to people: men, children, women, members, man, americans, christians, things,
# Nearest to who: he, which, often, she, martel, never, also, that,
# Nearest to no: little, any, always, already, only, physicists, roms, stimulated,
# Nearest to up: out, down, off, them, him, back, compressibility, urbanisation,
# Nearest to not: still, now, actually, generally, we, never, transpose, it,
# Nearest to a: another, every, the, any, cassell, poetical, chic, ballard,
# Nearest to by: through, with, while, using, under, when, without, during,
# Nearest to american: british, european, australian, french, japanese, german, russian, awami,
# Average loss at step 92000: 3.400156
# Average loss at step 94000: 3.252845
# Average loss at step 96000: 3.359873
# Average loss at step 98000: 3.246965
# Average loss at step 100000: 3.352596
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to s: whose, his, amnon, your, pacifica, insecticide, her, samael,
# Nearest to b: d, abbas, wellcome, c, farad, shoshone, cleaners, spliced,
# Nearest to about: rohan, appearances, approximately, bladed, prosecution, sing, amusing, imperceptible,
# Nearest to he: she, it, they, there, who, we, never, this,
# Nearest to over: around, within, off, forgeries, through, caviar, thames, stimson,
# Nearest to its: their, his, the, her, your, levied, saxony, some,
# Nearest to have: had, has, were, are, be, having, tend, require,
# Nearest to people: men, children, women, speakers, students, things, americans, members,
# Nearest to who: he, never, she, actually, often, also, still, devries,
# Nearest to no: any, little, always, only, roms, another, zout, funimation,
# Nearest to up: out, off, down, them, him, back, compressibility, paucity,
# Nearest to not: still, never, actually, now, t, also, considered, they,
# Nearest to a: another, any, the, cassell, every, hamill, wexford, leicester,
# Nearest to by: through, without, during, using, been, lx, under, blender,
# Nearest to american: british, canadian, australian, japanese, locus, russian, french, awami,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# # Problem
# An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %%
data_index = 0

# skip_window: int : How many words to consider left and right.
def generate_cbow_batch(batch_size, skip_window):
  global data_index
#   assert batch_size % num_skips == 0
#   assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, skip_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
#   buffer = []
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
  for i in range(batch_size):
    batch[i] = list(buffer)[:skip_window] + list(buffer)[skip_window+1:]
    labels[i] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels

# %%
# CBOW model

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  # note the different input dimensions for the CBOW model
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # note the sum over the context embeddings for the CBOW model
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.reduce_sum(embed, 1)

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.904450
# Nearest to but: avar, yy, outcast, vivisection, advancements, examining, sdi, mondo,
# Nearest to called: berklee, demonstrably, mph, steady, arching, arkansas, chukotka, diedrich,
# Nearest to seven: teleportation, ranges, derive, dispersing, wholesome, garry, mamoru, v,
# Nearest to also: emanating, forman, delocalised, tsim, itanium, seems, bombings, antennas,
# Nearest to from: anhydride, brouwer, hyrcanus, mack, roth, hughes, definitional, sindhi,
# Nearest to or: priam, hummel, pellet, insulation, affluent, banach, dru, parnell,
# Nearest to by: mpa, fancy, ronaldo, pyotr, triumvirate, coney, pisano, imperfectly,
# Nearest to th: javascript, resurgent, moritz, chandragupta, skopje, authorization, indestructible, aquifer,
# Nearest to were: payloads, fortuitous, assaulting, jorge, regenerate, torsion, engineered, fz,
# Nearest to after: norte, thrives, lu, baptisms, dumas, eui, mendicant, drone,
# Nearest to only: virus, gently, amenable, literal, slices, cbd, atreides, workplace,
# Nearest to be: end, turkmen, bl, frenchman, copycat, sir, polisario, snack,
# Nearest to at: colloquialism, silverstein, bollywood, mennonites, hull, adaption, conformance, runic,
# Nearest to for: mesa, click, shula, evaluated, sobib, ik, bicentennial, cabbie,
# Nearest to than: belgian, internecine, pannonia, disproportionately, heliogabalus, deadly, burgos, cardinals,
# Nearest to one: press, ould, repurchase, secreting, arouse, playing, nearing, instigator,
# Average loss at step 2000: 4.097847
# Average loss at step 4000: 3.562915
# Average loss at step 6000: 3.390207
# Average loss at step 8000: 3.250673
# Average loss at step 10000: 3.183652
# Nearest to but: however, springsteen, will, quantitatively, although, ecclesiology, which, that,
# Nearest to called: arkansas, fudge, inconvenient, medical, still, theroux, welcomed, hatch,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to also: now, not, often, who, peremptory, sometimes, which, fonda,
# Nearest to from: into, in, during, mieszko, courtesan, before, sig, stink,
# Nearest to or: and, than, label, bottling, umami, highlanders, tipped, flatted,
# Nearest to by: pyrrhus, utraquists, mpa, briefs, formats, minimalistic, pledging, entertainers,
# Nearest to th: gmail, three, seven, eventually, javascript, intelsat, resurgent, assured,
# Nearest to were: are, was, had, ascend, have, been, bayes, rennet,
# Nearest to after: before, when, thrives, baptisms, norte, lu, leena, from,
# Nearest to only: jagged, intestine, literal, slices, genetically, galleys, professing, commemorations,
# Nearest to be: lead, according, have, been, venereal, provide, doohan, was,
# Nearest to at: in, badly, udi, if, chips, rouen, headlining, bollywood,
# Nearest to for: with, option, islami, rutger, tydings, homeschooling, if, una,
# Nearest to than: or, deadly, jalal, rosalynn, diligently, ensure, dulles, toomer,
# Nearest to one: two, viollet, six, four, eight, previous, tian, inspectors,
# Average loss at step 12000: 3.202979
# Average loss at step 14000: 3.163326
# Average loss at step 16000: 3.181674
# Average loss at step 18000: 3.131346
# Average loss at step 20000: 2.996331
# Nearest to but: however, and, which, although, denunciations, though, see, uranium,
# Nearest to called: inconvenient, defined, mayr, retold, aur, pds, lucille, rapcore,
# Nearest to seven: eight, six, nine, five, three, four, zero, two,
# Nearest to also: now, which, still, often, usually, generally, who, sewing,
# Nearest to from: into, before, chobert, through, during, dramatization, between, armistice,
# Nearest to or: and, than, organelle, semantically, bassoons, gion, frf, excommunicate,
# Nearest to by: fancy, pyrrhus, potawatomi, erythematosus, torrent, briefs, mpa, utraquists,
# Nearest to th: intelsat, six, eight, nostrand, nine, nd, seven, four,
# Nearest to were: are, have, was, been, had, befall, be, clockwork,
# Nearest to after: before, when, baptisms, thrives, through, lner, during, madden,
# Nearest to only: separatists, literal, sacher, kathleen, jagged, mikhailovich, professing, favorites,
# Nearest to be: been, is, arctocephalus, have, were, according, was, lead,
# Nearest to at: in, on, during, reinforcing, bearable, sequencer, silverstein, jutsu,
# Nearest to for: vigor, of, if, avery, in, blockage, after, when,
# Nearest to than: or, rosalynn, diligently, jalal, deadly, toomer, imams, pronounces,
# Nearest to one: two, six, exempted, secreting, seven, rowe, whampoa, stolen,
# Average loss at step 22000: 3.074779
# Average loss at step 24000: 3.041861
# Average loss at step 26000: 3.004626
# Average loss at step 28000: 3.032545
# Average loss at step 30000: 3.006235
# Nearest to but: however, and, see, which, although, than, nose, denunciations,
# Nearest to called: inconvenient, defined, purchasers, retold, known, used, arkansas, named,
# Nearest to seven: eight, nine, six, four, five, three, zero, two,
# Nearest to also: now, still, which, often, usually, actually, sometimes, peremptory,
# Nearest to from: into, through, in, during, courtesan, sig, within, after,
# Nearest to or: and, insured, moratorium, bhfuil, frf, than, molson, punching,
# Nearest to by: pyrrhus, workability, satsuma, minimalistic, briefs, fancy, handoff, through,
# Nearest to th: five, six, four, ovary, bc, castille, unscr, nd,
# Nearest to were: are, have, was, had, been, include, befall, undermine,
# Nearest to after: before, when, during, through, without, while, from, baptisms,
# Nearest to only: mikhailovich, always, separatists, windsurfing, abercorn, overwhelming, until, still,
# Nearest to be: been, provide, lead, being, was, become, according, venereal,
# Nearest to at: during, in, falsehood, announced, bearable, reinforcing, udi, satires,
# Nearest to for: if, without, when, pleading, una, fast, malatesta, or,
# Nearest to than: rosalynn, much, but, diligently, perceptual, toomer, deadly, or,
# Nearest to one: two, six, homilies, secreting, four, cumont, five, embassies,
# Average loss at step 32000: 2.829653
# Average loss at step 34000: 2.962549
# Average loss at step 36000: 2.946157
# Average loss at step 38000: 2.946777
# Average loss at step 40000: 2.931615
# Nearest to but: however, and, although, while, than, which, though, or,
# Nearest to called: named, known, defined, considered, used, purchasers, inconvenient, selected,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to also: now, still, often, actually, usually, sometimes, which, generally,
# Nearest to from: through, into, during, by, after, within, cgs, using,
# Nearest to or: and, while, than, martingale, although, kyle, but, hfs,
# Nearest to by: when, from, erythematosus, veronica, through, pyrrhus, fancy, torrent,
# Nearest to th: five, four, six, eight, seven, patched, unscr, third,
# Nearest to were: are, have, had, was, been, include, be, befall,
# Nearest to after: before, when, during, without, despite, from, if, wildcat,
# Nearest to only: always, separatists, first, sacher, mikhailovich, still, abercorn, overwhelming,
# Nearest to be: been, become, have, is, being, was, lead, were,
# Nearest to at: during, anxiolytic, satires, udi, aglaulus, carrey, near, thinner,
# Nearest to for: without, when, una, courtesy, after, although, including, repertory,
# Nearest to than: much, rosalynn, but, deadly, or, alcor, diligently, jalal,
# Nearest to one: two, lasker, broughton, ers, workman, seven, damme, rowe,
# Average loss at step 42000: 2.954753
# Average loss at step 44000: 2.957979
# Average loss at step 46000: 2.907982
# Average loss at step 48000: 2.870703
# Average loss at step 50000: 2.855775
# Nearest to but: however, although, and, while, see, do, deployable, transplanted,
# Nearest to called: named, known, defined, used, lucille, inconvenient, considered, selected,
# Nearest to seven: eight, nine, six, five, four, zero, three, two,
# Nearest to also: now, still, often, actually, sometimes, usually, which, never,
# Nearest to from: through, into, during, in, before, within, pranksters, under,
# Nearest to or: and, than, conductivity, bassoons, while, insured, frf, but,
# Nearest to by: veronica, minimalistic, when, through, during, heschel, towards, potawatomi,
# Nearest to th: third, second, rd, bc, nineteenth, unscr, intelsat, nd,
# Nearest to were: are, had, have, was, specially, befall, been, while,
# Nearest to after: before, when, during, without, despite, while, if, though,
# Nearest to only: always, no, even, still, separatists, sacher, not, never,
# Nearest to be: been, become, have, introduce, provide, is, easily, are,
# Nearest to at: during, in, under, headlining, near, satires, aglaulus, inside,
# Nearest to for: without, while, although, when, against, inefficiency, mesa, conveys,
# Nearest to than: or, rosalynn, much, diligently, alcor, jalal, but, and,
# Nearest to one: canada, two, hammadi, babylon, rowe, viollet, ers, broughton,
# Average loss at step 52000: 2.888369
# Average loss at step 54000: 2.866523
# Average loss at step 56000: 2.860621
# Average loss at step 58000: 2.750278
# Average loss at step 60000: 2.832604
# Nearest to but: however, although, and, see, while, though, jonny, progressing,
# Nearest to called: named, known, defined, considered, selected, inconvenient, skull, used,
# Nearest to seven: six, five, four, eight, nine, three, zero, two,
# Nearest to also: now, still, often, actually, usually, generally, which, sometimes,
# Nearest to from: through, into, during, after, within, in, by, before,
# Nearest to or: and, than, while, though, introductory, conductivity, iy, propulsion,
# Nearest to by: potawatomi, pyrrhus, leninist, fancy, through, from, lymph, towards,
# Nearest to th: second, third, nineteenth, bc, rd, seventeenth, nd, proterozoic,
# Nearest to were: are, had, was, have, be, been, those, befall,
# Nearest to after: before, when, during, without, despite, if, afterwards, from,
# Nearest to only: always, actually, all, either, still, abercorn, bagoas, reach,
# Nearest to be: been, become, being, have, provide, were, lead, introduce,
# Nearest to at: during, near, in, aglaulus, on, headlining, within, minyan,
# Nearest to for: without, after, avery, if, sobib, against, whitfield, client,
# Nearest to than: or, rosalynn, diligently, even, alcor, courtly, jalal, swnts,
# Nearest to one: two, four, six, seven, eight, embassies, five, broughton,
# Average loss at step 62000: 2.833335
# Average loss at step 64000: 2.778036
# Average loss at step 66000: 2.759609
# Average loss at step 68000: 2.718811
# Average loss at step 70000: 2.789209
# Nearest to but: however, although, and, though, while, he, than, yet,
# Nearest to called: named, known, selected, considered, defined, laid, kapoor, used,
# Nearest to seven: five, six, eight, nine, four, three, zero, two,
# Nearest to also: now, often, still, usually, actually, generally, never, always,
# Nearest to from: through, into, during, sig, within, before, after, courtesan,
# Nearest to or: and, than, though, frf, annette, while, insured, iy,
# Nearest to by: potawatomi, including, fancy, tycoon, with, while, through, under,
# Nearest to th: third, nineteenth, rd, second, nd, sixth, seventeenth, fifth,
# Nearest to were: are, was, have, include, been, had, be, became,
# Nearest to after: before, when, during, despite, without, afterwards, upon, if,
# Nearest to only: separatists, always, either, best, abercorn, mikhailovich, tributary, all,
# Nearest to be: been, become, is, being, were, have, remain, introduce,
# Nearest to at: near, aglaulus, on, during, reinforcing, within, in, under,
# Nearest to for: avery, when, after, if, against, homeschooling, whitfield, amaziah,
# Nearest to than: rosalynn, or, alcor, deadly, diligently, much, gerardus, router,
# Nearest to one: two, three, babylon, rowe, eradication, ers, seven, writeups,
# Average loss at step 72000: 2.801595
# Average loss at step 74000: 2.647981
# Average loss at step 76000: 2.801825
# Average loss at step 78000: 2.827155
# Average loss at step 80000: 2.780118
# Nearest to but: however, although, though, while, and, which, until, augustinian,
# Nearest to called: named, known, inconvenient, kapoor, formed, selected, laid, thereupon,
# Nearest to seven: six, eight, five, nine, four, three, zero, two,
# Nearest to also: now, often, still, generally, usually, actually, sometimes, never,
# Nearest to from: through, into, during, within, after, chobert, courtesan, sig,
# Nearest to or: and, than, though, hfs, daley, insured, thom, wye,
# Nearest to by: including, towards, potawatomi, toward, through, under, without, while,
# Nearest to th: third, nineteenth, rd, nd, seventeenth, second, sixth, six,
# Nearest to were: are, have, was, include, had, including, been, xxvii,
# Nearest to after: before, during, despite, when, without, while, upon, for,
# Nearest to only: mikhailovich, always, no, separatists, all, best, either, abercorn,
# Nearest to be: become, been, remain, lead, is, easily, provide, was,
# Nearest to at: in, during, reinforcing, near, within, anxiolytic, aglaulus, eurystheus,
# Nearest to for: without, after, despite, when, while, amaziah, avery, homeschooling,
# Nearest to than: rosalynn, much, or, alcor, yggdrasil, flexible, charming, router,
# Nearest to one: two, four, seven, eradication, seduced, three, six, mph,
# Average loss at step 82000: 2.666796
# Average loss at step 84000: 2.777053
# Average loss at step 86000: 2.734952
# Average loss at step 88000: 2.758150
# Average loss at step 90000: 2.735109
# Nearest to but: however, although, though, while, and, tretyakov, see, until,
# Nearest to called: named, known, formed, selected, considered, referred, laid, defined,
# Nearest to seven: six, eight, nine, four, five, three, zero, two,
# Nearest to also: now, never, still, actually, often, usually, generally, which,
# Nearest to from: through, into, including, during, across, in, courtesan, within,
# Nearest to or: and, though, introductory, than, com, insured, but, gorky,
# Nearest to by: through, via, including, potawatomi, toward, towards, fancy, minimalistic,
# Nearest to th: nineteenth, third, seventeenth, eight, six, sixth, second, fifth,
# Nearest to were: are, have, had, include, those, been, was, remain,
# Nearest to after: before, during, despite, when, without, upon, afterwards, if,
# Nearest to only: always, either, mikhailovich, no, abercorn, tributary, separatists, usually,
# Nearest to be: become, been, remain, being, have, cause, lead, easily,
# Nearest to at: near, during, in, reinforcing, benguela, inside, almost, sequencer,
# Nearest to for: when, despite, if, onto, after, without, avery, while,
# Nearest to than: rosalynn, or, alcor, much, but, even, yggdrasil, diligently,
# Nearest to one: two, four, eight, six, seven, rowe, three, eradication,
# Average loss at step 92000: 2.683274
# Average loss at step 94000: 2.726534
# Average loss at step 96000: 2.704761
# Average loss at step 98000: 2.369299
# Average loss at step 100000: 2.399741
# Nearest to but: however, and, although, though, while, until, did, which,
# Nearest to called: named, known, selected, referred, used, laid, thereupon, defined,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to also: still, now, actually, often, never, which, generally, currently,
# Nearest to from: through, into, courtesan, without, keeps, via, pranksters, before,
# Nearest to or: and, than, though, com, thom, degas, sanctuary, especial,
# Nearest to by: including, potawatomi, through, towards, torrent, fancy, pyrrhus, toward,
# Nearest to th: nd, nineteenth, fifth, sixth, third, second, seventeenth, patched,
# Nearest to were: are, have, include, was, had, contain, remain, tend,
# Nearest to after: before, despite, when, during, without, following, while, for,
# Nearest to only: first, either, always, last, separatists, best, mikhailovich, grenadines,
# Nearest to be: been, become, remain, have, being, was, is, were,
# Nearest to at: during, near, in, reinforcing, on, aglaulus, falsehood, after,
# Nearest to for: after, without, when, avery, despite, against, shandy, before,
# Nearest to than: or, rosalynn, much, alcor, becoming, diligently, jalal, backronym,
# Nearest to one: lasker, two, cumont, elan, rowe, chicago, isospin, homilies,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
